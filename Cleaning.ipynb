# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
import warnings
from IPython.display import display
from sklearn.model_selection import train_test_split 
sb.set() 
warnings.filterwarnings('ignore')
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Data Import

# %%
data = pd.read_csv("Housing.csv")
data.head()
# Out:
#       month        town flat_type block        street_name storey_range  \
# 0  3/1/2012  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1  3/1/2012  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2  3/1/2012  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3  3/1/2012  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4  3/1/2012  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0              45        Improved                 1986      250000.0
# 1              44        Improved                 1980      265000.0
# 2              68  New Generation                 1980      315000.0
# 3              67  New Generation                 1984      320000.0
# 4              67  New Generation                 1980      321000.0

# %% [markdown]
# ## Data cleaning

# %%
# Removing empty spaces from the columns
data.columns = data.columns.str.strip()

# Removing leading and trailing whitespaces
data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Removing duplicate rows
data.drop_duplicates(inplace=True)

# Data types of columns
print("\nData types of columns:")
print(data.dtypes)

# Missing values
print("\nMissing values:")
print(data.isnull().sum())

# Dropping the rows with resale_price and floor_area_sqm
data = data.dropna(subset=['floor_area_sqm'])
data = data.dropna(subset=['resale_price'])
# Out:
# Data types of columns:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                  int64
# flat_model                     object
# lease_commence_date             int64
# resale_price                  float64
# year                            int64
# dtype: object
#
# Missing values:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# year                   0
# dtype: int64

# %%
# Convert the 'month' column to datetime format
data['month'] = pd.to_datetime(data['month'], format='%d/%m/%Y')

# Extract the year from the 'month' column and create a new column named 'year'
data['year'] = data['month'].dt.year

# Save the DataFrame back to a CSV file
data.to_csv('cleaned-Housing.csv', index=False)  # Set index=False to avoid saving the DataFrame index as a column

# %%
# Define the lower and upper quantile thresholds
lower_quartile = data['resale_price'].quantile(0.25)
upper_quartile = data['resale_price'].quantile(0.75)
interquartile_range = upper_quartile - lower_quartile
lower_threshold = lower_quartile - 1.5*interquartile_range
upper_threshold = upper_quartile + 1.5*interquartile_range

# Filter out the outliers based on the resale price column
data = data[(data['resale_price'] >= lower_threshold) & (data['resale_price'] <= upper_threshold)]

# %%
pd.options.display.max_columns = None
display(data)
# Out:
#            month        town  flat_type block        street_name storey_range  \
# 0     2012-01-03  ANG MO KIO     2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1     2012-01-03  ANG MO KIO     2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2     2012-01-03  ANG MO KIO     3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3     2012-01-03  ANG MO KIO     3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4     2012-01-03  ANG MO KIO     3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
# ...          ...         ...        ...   ...                ...          ...
# 52198 2014-01-12      YISHUN     5 ROOM   816       YISHUN ST 81     10 TO 12
# 52199 2014-01-12      YISHUN  EXECUTIVE   325        YISHUN CTRL     10 TO 12
# 52200 2014-01-12      YISHUN  EXECUTIVE   618     YISHUN RING RD     07 TO 09
# 52201 2014-01-12      YISHUN  EXECUTIVE   277       YISHUN ST 22     07 TO 09
# 52202 2014-01-12      YISHUN  EXECUTIVE   277       YISHUN ST 22     04 TO 06
#
#        floor_area_sqm      flat_model  lease_commence_date  resale_price  year
# 0                  45        Improved                 1986      250000.0  2012
# 1                  44        Improved                 1980      265000.0  2012
# 2                  68  New Generation                 1980      315000.0  2012
# 3                  67  New Generation                 1984      320000.0  2012
# 4                  67  New Generation                 1980      321000.0  2012
# ...               ...             ...                  ...           ...   ...
# 52198             122        Improved                 1988      580000.0  2014
# 52199             146      Maisonette                 1988      540000.0  2014
# 52200             164       Apartment                 1992      738000.0  2014
# 52201             152      Maisonette                 1985      592000.0  2014
# 52202             146      Maisonette                 1985      545000.0  2014
#
# [50549 rows x 11 columns]

# %% [markdown]
# ## Train-test split

# %%
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
train_data.head()
# Out:
#            month         town flat_type block          street_name  \
# 2680  2012-01-04  BUKIT BATOK    4 ROOM   236  BT BATOK EAST AVE 5
# 32722 2013-01-10  BUKIT BATOK    4 ROOM   410  BT BATOK WEST AVE 4
# 33631 2013-01-10    TOA PAYOH    3 ROOM   232      LOR 8 TOA PAYOH
# 50323 2014-01-11      PUNGGOL    5 ROOM  638B           PUNGGOL DR
# 51497 2014-01-12  JURONG WEST    3 ROOM   464    JURONG WEST ST 41
#
#       storey_range  floor_area_sqm         flat_model  lease_commence_date  \
# 2680      01 TO 05              98     New Generation                 1985
# 32722     10 TO 12              99     New Generation                 1988
# 33631     04 TO 06              76           Improved                 1976
# 50323     07 TO 09             112  Premium Apartment                 2005
# 51497     04 TO 06              73            Model A                 1984
#
#        resale_price  year
# 2680       420000.0  2012
# 32722      390000.0  2013
# 33631      370000.0  2013
# 50323      470000.0  2014
# 51497      300000.0  2014

# %%
test_data.head()
# Out:
#            month           town flat_type block          street_name  \
# 13560 2012-01-09  CHOA CHU KANG    4 ROOM   425  CHOA CHU KANG AVE 4
# 14833 2012-01-09         YISHUN    4 ROOM   829         YISHUN ST 81
# 27701 2013-01-06    JURONG WEST    3 ROOM   186         BOON LAY AVE
# 28140 2013-01-06       TAMPINES    4 ROOM   338       TAMPINES ST 33
# 50620 2014-01-11       TAMPINES    5 ROOM  864A       TAMPINES ST 83
#
#       storey_range  floor_area_sqm flat_model  lease_commence_date  \
# 13560     04 TO 06             104    Model A                 1992
# 14833     07 TO 09             103    Model A                 1988
# 27701     19 TO 21              68   Improved                 1975
# 28140     01 TO 03             106    Model A                 1995
# 50620     07 TO 09             122   Improved                 1988
#
#        resale_price  year
# 13560      430000.0  2012
# 14833      500000.0  2012
# 27701      315000.0  2013
# 28140      445000.0  2013
# 50620      515000.0  2014

# %% [markdown]
# ## Export

# %%
data.to_csv("cleaned-Housing.csv", index=False)
train_data.to_csv("train-Housing.csv", index=False)
test_data.to_csv("test-Housing.csv", index=False)
