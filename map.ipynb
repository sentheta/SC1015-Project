# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestRegressor
from datetime import datetime
import folium
sb.set()

# %%
data = pd.read_csv("cleaned-Housing.csv")
data.head()
# Out:
#    Unnamed: 0     month        town flat_type block        street_name  \
# 0           0  3/1/2012  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4
# 1           1  3/1/2012  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8
# 2           2  3/1/2012  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4
# 3           3  3/1/2012  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10
# 4           4  3/1/2012  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5
#
#   storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 0     06 TO 10              45        Improved                 1986
# 1     01 TO 05              44        Improved                 1980
# 2     06 TO 10              68  New Generation                 1980
# 3     01 TO 05              67  New Generation                 1984
# 4     06 TO 10              67  New Generation                 1980
#
#    resale_price
# 0      250000.0
# 1      265000.0
# 2      315000.0
# 3      320000.0
# 4      321000.0

# %%
# Coordinate of each town
# Source: database.earth, latlong.info, latitude.to, www.gardencitysingapore.com
townCoords = {
    "ANG MO KIO": [1.3698, 103.8461],
    "BEDOK": [1.3236, 103.9273],
    "BISHAN": [1.3499986, 103.8499966],
    "BUKIT BATOK": [1.3496, 103.7528],
    "BUKIT MERAH": [1.2858300, 103.8194400],
    "BUKIT PANJANG": [1.3786, 103.7626],
    "BUKIT TIMAH": [1.3294, 103.8021],
    "CENTRAL AREA": [1.2895, 103.8143],
    "CHOA CHU KANG": [1.3833318, 103.749997],
    "CLEMENTI": [1.30918042994, 103.75914363],
    "GEYLANG": [1.3182, 103.8871],
    "HOUGANG": [1.3736, 103.8867],
    "JURONG EAST": [1.32399537068, 103.737298717],
    "JURONG WEST": [1.3396, 103.7073],
    "KALLANG/WHAMPOA": [1.3106, 103.866],
    "MARINE PARADE": [1.3030, 103.9072],
    "PASIR RIS": [1.3739, 103.9493],
    "PUNGGOL": [1.4051, 103.9023],
    "QUEENSTOWN": [1.2994400, 103.8058300],
    "SEMBAWANG": [1.4491, 103.8201],
    "SENGKANG": [1.3901, 103.8952],
    "SERANGOON": [1.3496, 103.8737],
    "TAMPINES": [1.3547, 103.9437],
    "TOA PAYOH": [1.3354, 103.8497],
    "WOODLANDS": [1.43801, 103.78877],
    "YISHUN": [1.4293, 103.8355]
}

# %%
sgmap = folium.Map(location=[1.3666,103.800], zoom_start=12,tiles="OpenStreetMap")
# folium.CircleMarker(location=townCoords["SERANGOON"]).add_to(sgmap)
for s in townCoords:
    folium.CircleMarker(location=townCoords[s], radius=10, color="#0000AA", fill=True, popup=s).add_to(sgmap)

sgmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_483e8caf0b07fdcd02927eec12620b9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_483e8caf0b07fdcd02927eec12620b9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_483e8caf0b07fdcd02927eec12620b9e = L.map(
#                 &quot;map_483e8caf0b07fdcd02927eec12620b9e&quot;,
#                 {
#                     center: [1.3666, 103.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1ea49cbcd1d16a2b06ab2dc554558ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f1ea49cbcd1d16a2b06ab2dc554558ab.addTo(map_483e8caf0b07fdcd02927eec12620b9e);
#
#
#             var circle_marker_b6cc499da07b3910e052d9e456f98630 = L.circleMarker(
#                 [1.3698, 103.8461],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_483e8caf0b07fdcd02927eec12620b9e);
#
#
#         var popup_9f59c19114f927bad1d90adbec1471ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b36b8091fd011074ea4b434f0546bff = $(`&lt;div id=&quot;html_1b36b8091fd011074ea4b434f0546bff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ANG MO KIO&lt;/div&gt;`)[0];
#                 popup_9f59c19114f927bad1d90adbec1471ce.setContent(html_1b36b8091fd011074ea4b434f0546bff);
#
#
#
#         circle_marker_b6cc499da07b3910e052d9e456f98630.bindPopup(popup_9f59c19114f927bad1d90adbec1471ce)
#         ;
#
#
#
#
#             var circle_marker_cd0716995f4eb08020504ee00516748a = L.circleMarker(
#                 [1.3236, 103.9273],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_483e8caf0b07fdcd02927eec12620b9e);
#
#
#         var popup_08b694eace2ec2ceb2010a5789d417d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_364b7ead17d168ddfe9d78549703c1f8 = $(`&lt;div id=&quot;html_364b7ead17d168ddfe9d78549703c1f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BEDOK&lt;/div&gt;`)[0];
#                 popup_08b694eace2ec2ceb2010a5789d417d1.setContent(html_364b7ead17d168ddfe9d78549703c1f8);
#
#
#
#         circle_marker_cd0716995f4eb08020504ee00516748a.bindPopup(popup_08b694eace2ec2ceb2010a5789d417d1)
#         ;
#
#
#
#
#             var circle_marker_f8a685d23faf6702fa77f262e80571f5 = L.circleMarker(
#                 [1.3499986, 103.8499966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_483e8caf0b07fdcd02927eec12620b9e);
#
#
#         var popup_41857d59596f31d2120937cf3896361c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76430f306291f47827b88d3374dd4994 = $(`&lt;div id=&quot;html_76430f306291f47827b88d3374dd4994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BISHAN&lt;/div&gt;`)[0];
#                 popup_41857d59596f31d2120937cf3896361c.setContent(html_76430f306291f47827b88d3374dd4994);
#
#
#
#         circle_marker_f8a685d23faf6702fa77f262e80571f5.bindPopup(popup_41857d59596f31d2120937cf3896361c)
#         ;
#
#
#
#
#             var circle_marker_c8a07930d67aa1ee4cc5910f9f9d3d6f = L.circleMarker(
#                 [1.3496, 103.7528],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fillOpacity&quot;: 0.2, &quot;

# %%
sgmap.save("map.html")

# %%
# Render map, can pass in filtered/specific data
# Radius based on count of each town
# To modify circle size, tweak `radiusScaler` parameter
def renderMap(data, radiusScaler=100):
    global sgmap
    for townName in townCoords:
        print(townName)
        count = 0
        for s in data["town"]:
            count += townName==s
        radius = count / radiusScaler
#         radius = data["town"].count(s)/10
        popup = townName + "\n" + str(count)
        folium.CircleMarker(location=townCoords[townName], radius=radius, color="#0000AA", fill=True, popup=popup).add_to(sgmap)

sgmap = folium.Map(location=[1.3666,103.800], zoom_start=12,tiles="OpenStreetMap")    
renderMap(data, 100)
sgmap
# Out:
# ANG MO KIO
# BEDOK
# BISHAN
# BUKIT BATOK
# BUKIT MERAH
# BUKIT PANJANG
# BUKIT TIMAH
# CENTRAL AREA
# CHOA CHU KANG
# CLEMENTI
# GEYLANG
# HOUGANG
# JURONG EAST
# JURONG WEST
# KALLANG/WHAMPOA
# MARINE PARADE
# PASIR RIS
# PUNGGOL
# QUEENSTOWN
# SEMBAWANG
# SENGKANG
# SERANGOON
# TAMPINES
# TOA PAYOH
# WOODLANDS
# YISHUN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abf9a2da787295e66fdc445fff90bd05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abf9a2da787295e66fdc445fff90bd05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abf9a2da787295e66fdc445fff90bd05 = L.map(
#                 &quot;map_abf9a2da787295e66fdc445fff90bd05&quot;,
#                 {
#                     center: [1.3666, 103.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dadff03a7322b648e582e3648e5e260 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9dadff03a7322b648e582e3648e5e260.addTo(map_abf9a2da787295e66fdc445fff90bd05);
#
#
#             var circle_marker_24bfc726258f53a71f5a9772fc0ffed7 = L.circleMarker(
#                 [1.3698, 103.8461],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 78.93, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf9a2da787295e66fdc445fff90bd05);
#
#
#         var popup_7510976f3a96e6b0811702c0aba7abbb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d807d2c90af911713a4ae4bc87bf476d = $(`&lt;div id=&quot;html_d807d2c90af911713a4ae4bc87bf476d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ANG MO KIO 7893&lt;/div&gt;`)[0];
#                 popup_7510976f3a96e6b0811702c0aba7abbb.setContent(html_d807d2c90af911713a4ae4bc87bf476d);
#
#
#
#         circle_marker_24bfc726258f53a71f5a9772fc0ffed7.bindPopup(popup_7510976f3a96e6b0811702c0aba7abbb)
#         ;
#
#
#
#
#             var circle_marker_d4e1ae14cb18d0e93c4538d1b164862b = L.circleMarker(
#                 [1.3236, 103.9273],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100.67, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf9a2da787295e66fdc445fff90bd05);
#
#
#         var popup_7a3f2d2f961ce501d6291629aa8c25ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63629feb40f5efc772f22307dabcc5bb = $(`&lt;div id=&quot;html_63629feb40f5efc772f22307dabcc5bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BEDOK 10067&lt;/div&gt;`)[0];
#                 popup_7a3f2d2f961ce501d6291629aa8c25ec.setContent(html_63629feb40f5efc772f22307dabcc5bb);
#
#
#
#         circle_marker_d4e1ae14cb18d0e93c4538d1b164862b.bindPopup(popup_7a3f2d2f961ce501d6291629aa8c25ec)
#         ;
#
#
#
#
#             var circle_marker_f40b7ac497b9a5e6f28dcb7fe947c3e4 = L.circleMarker(
#                 [1.3499986, 103.8499966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 31.26, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf9a2da787295e66fdc445fff90bd05);
#
#
#         var popup_9d978bb86b6f7b322748d27d46099512 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6625a4b132230e356d792e5c58735d49 = $(`&lt;div id=&quot;html_6625a4b132230e356d792e5c58735d49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BISHAN 3126&lt;/div&gt;`)[0];
#                 popup_9d978bb86b6f7b322748d27d46099512.setContent(html_6625a4b132230e356d792e5c58735d49);
#
#
#
#         circle_marker_f40b7ac497b9a5e6f28dcb7fe947c3e4.bindPopup(popup_9d978bb86b6f7b322748d27d46099512)
#         ;
#
#
#
#
#             var circle_marker_ee9b409e6ed8ef72a3d19e3a1c9489bf = L.circleMarker(
#                 [1.3496, 103.7528],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000AA&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0000AA&quot;, &quot;fill
